# %%
# !pip install hyperas
# Out:
# Collecting hyperas
#   Downloading https://files.pythonhosted.org/packages/04/34/87ad6ffb42df9c1fa9c4c906f65813d42ad70d68c66af4ffff048c228cd4/hyperas-0.4.1-py3-none-any.whl
# Requirement already satisfied: keras in /usr/local/lib/python3.6/dist-packages (from hyperas) (2.2.5)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.6/dist-packages (from hyperas) (5.6.1)
# Requirement already satisfied: hyperopt in /usr/local/lib/python3.6/dist-packages (from hyperas) (0.1.2)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.6/dist-packages (from hyperas) (0.3)
# Requirement already satisfied: jupyter in /usr/local/lib/python3.6/dist-packages (from hyperas) (1.0.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.6/dist-packages (from hyperas) (5.0.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras->hyperas) (3.13)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras->hyperas) (1.4.1)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from keras->hyperas) (1.0.8)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from keras->hyperas) (1.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras->hyperas) (2.8.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras->hyperas) (1.17.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras->hyperas) (1.12.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.6/dist-packages (from nbconvert->hyperas) (3.1.0)
# Requirement already satisfied: jinja2>=2.4 in /usr/local/lib/python3.6/dist-packages (from nbconvert->hyperas) (2.10.3)
# Requirement already satisfied: testpath in /usr/local/lib/python3.6/dist-packages (from nbconvert->hyperas) (0.4.4)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.6/dist-packages (from nbconvert->hyperas) (4.3.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert->hyperas) (1.4.2)
# Requirement already satisfied: pygments in /usr/local/lib/python3.6/dist-packages (from nbconvert->hyperas) (2.1.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert->hyperas) (0.8.4)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.6/dist-packages (from nbconvert->hyperas) (4.6.1)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.6/dist-packages (from nbconvert->hyperas) (0.6.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.6/dist-packages (from hyperopt->hyperas) (2.4)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from hyperopt->hyperas) (0.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from hyperopt->hyperas) (4.28.1)
# Requirement already satisfied: pymongo in /usr/local/lib/python3.6/dist-packages (from hyperopt->hyperas) (3.10.0)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.6/dist-packages (from jupyter->hyperas) (5.2.0)
# Requirement already satisfied: notebook in /usr/local/lib/python3.6/dist-packages (from jupyter->hyperas) (5.2.2)
# Requirement already satisfied: qtconsole in /usr/local/lib/python3.6/dist-packages (from jupyter->hyperas) (4.6.0)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.6/dist-packages (from jupyter->hyperas) (4.6.1)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.6/dist-packages (from jupyter->hyperas) (7.5.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.6/dist-packages (from nbformat->hyperas) (2.6.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from nbformat->hyperas) (0.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.6/dist-packages (from bleach->nbconvert->hyperas) (0.5.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2>=2.4->nbconvert->hyperas) (1.1.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from traitlets>=4.2->nbconvert->hyperas) (4.4.1)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from jupyter-console->jupyter->hyperas) (1.0.18)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.6/dist-packages (from jupyter-console->jupyter->hyperas) (5.3.4)
# Requirement already satisfied: ipython in /usr/local/lib/python3.6/dist-packages (from jupyter-console->jupyter->hyperas) (5.5.0)
# Requirement already satisfied: tornado>=4 in /usr/local/lib/python3.6/dist-packages (from notebook->jupyter->hyperas) (4.5.3)
# Requirement already satisfied: terminado>=0.3.3; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from notebook->jupyter->hyperas) (0.8.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /usr/local/lib/python3.6/dist-packages (from ipywidgets->jupyter->hyperas) (3.5.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.6/dist-packages (from prompt-toolkit<2.0.0,>=1.0.0->jupyter-console->jupyter->hyperas) (0.1.8)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from jupyter-client->jupyter-console->jupyter->hyperas) (2.6.1)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.6/dist-packages (from jupyter-client->jupyter-console->jupyter->hyperas) (17.0.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.6/dist-packages (from ipython->jupyter-console->jupyter->hyperas) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.6/dist-packages (from ipython->jupyter-console->jupyter->hyperas) (42.0.2)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.6/dist-packages (from ipython->jupyter-console->jupyter->hyperas) (0.8.1)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from ipython->jupyter-console->jupyter->hyperas) (4.7.0)
# Requirement already satisfied: ptyprocess; os_name != "nt" in /usr/local/lib/python3.6/dist-packages (from terminado>=0.3.3; sys_platform != "win32"->notebook->jupyter->hyperas) (0.6.0)
# Installing collected packages: hyperas
# Successfully installed hyperas-0.4.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from keras.datasets import fashion_mnist
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=12345)

# %%
X_train = X_train.reshape(48000, 784)
X_val = X_val.reshape(12000, 784)
X_test = X_test.reshape(10000, 784)
X_train = X_train.astype('float32')
X_val = X_val.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_val /= 255
X_test/= 255

# %%
from keras.utils import np_utils
nb_classes = 10 
Y_train = np_utils.to_categorical(y_train, nb_classes)
Y_val = np_utils.to_categorical(y_val, nb_classes)
Y_test= np_utils.to_categorical(y_test, nb_classes)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dropout,Dense,Activation
model = Sequential([
 Dense(10,input_shape=(784,),activation='softmax')
])
model.compile(optimizer=keras.optimizers.SGD(lr=0.1),
 loss='categorical_crossentropy',
 metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.

# %%
from hyperopt import Trials, STATUS_OK, tpe
from hyperas import optim
from hyperas.distributions import choice, uniform

# %%
def data():
    (X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()
    X_train, X_val, y_train, y_val = train_test_split(X_train,    y_train, test_size=0.2, random_state=12345)
    X_train = X_train.reshape(48000, 784)
    X_val = X_val.reshape(12000, 784)
    X_train = X_train.astype('float32')
    X_val = X_val.astype('float32')
    X_train /= 255
    X_val /= 255
    nb_classes = 10
    Y_train = np_utils.to_categorical(y_train, nb_classes)
    Y_val = np_utils.to_categorical(y_val, nb_classes)
    return X_train, Y_train, X_val, Y_val

# %%
def model(X_train, Y_train, X_val, Y_val):
    
    model = Sequential()
    model.add(Dense({{choice([128, 256, 512, 1024])}}, input_shape=(784,)))
    model.add(Activation({{choice(['relu', 'sigmoid'])}}))
    model.add(Dropout({{uniform(0, 1)}}))
    model.add(Dense({{choice([128, 256, 512, 1024])}}))
    model.add(Activation({{choice(['relu', 'sigmoid'])}}))
    model.add(Dropout({{uniform(0, 1)}}))
    
    if ({{choice(['two', 'three'])}}) == 'three':
        model.add(Dense({{choice([128, 256, 512, 1024])}}))
        model.add(Activation({{choice(['relu', 'sigmoid'])}}))
        model.add(Dropout({{uniform(0, 1)}}))
        
    model.add(Dense(10))
    model.add(Activation('softmax'))
    adam = keras.optimizers.Adam(lr={{choice([10**-3, 10**-2, 10**-1])}})
    rmsprop = keras.optimizers.RMSprop(lr={{choice([10**-3, 10**-2, 10**-1])}})
    sgd = keras.optimizers.SGD(lr={{choice([10**-3, 10**-2, 10**-1])}})
   
    choiceval = {{choice(['adam', 'sgd', 'rmsprop'])}}
    if choiceval == 'adam':
        optim = adam
    elif choiceval == 'rmsprop':
        optim = rmsprop
    else:
        optim = sgd
        
    model.compile(loss='categorical_crossentropy', metrics=['accuracy'],optimizer=optim)
    model.fit(X_train, Y_train,
              batch_size={{choice([128,256,512])}},
              nb_epoch=20,
              verbose=2,
              validation_data=(X_val, Y_val))
    score, acc = model.evaluate(X_val, Y_val, verbose=0)
    print('Test accuracy:', acc)
    return {'loss': -acc, 'status': STATUS_OK, 'model': model}

# %%
X_train, Y_train, X_val, Y_val = data()
best_run, best_model = optim.minimize(model=model,
                                      data=data,
                                      algo=tpe.suggest,
                                      max_evals=30,
                                      trials=Trials(),
                                      notebook_name='drive/My Drive/Colab Notebooks/DL_lab4')
# Out:
# >>> Imports:
# #coding=utf-8
#
# try:
#     from google.colab import drive
# except:
#     pass
#
# try:
#     from keras.datasets import fashion_mnist
# except:
#     pass
#
# try:
#     from sklearn.model_selection import train_test_split
# except:
#     pass
#
# try:
#     from keras.utils import np_utils
# except:
#     pass
#
# try:
#     import keras
# except:
#     pass
#
# try:
#     from keras.models import Sequential
# except:
#     pass
#
# try:
#     from keras.layers import Dropout, Dense, Activation
# except:
#     pass
#
# try:
#     from hyperopt import Trials, STATUS_OK, tpe
# except:
#     pass
#
# try:
#     from hyperas import optim
# except:
#     pass
#
# try:
#     from hyperas.distributions import choice, uniform
# except:
#     pass
#
# >>> Hyperas search space:
#
# def get_space():
#     return {
#         'Dense': hp.choice('Dense', [128, 256, 512, 1024]),
#         'Activation': hp.choice('Activation', ['relu', 'sigmoid']),
#         'Dropout': hp.uniform('Dropout', 0, 1),
#         'Dense_1': hp.choice('Dense_1', [128, 256, 512, 1024]),
#         'Activation_1': hp.choice('Activation_1', ['relu', 'sigmoid']),
#         'Dropout_1': hp.uniform('Dropout_1', 0, 1),
#         'if': hp.choice('if', ['two', 'three']),
#         'Dense_2': hp.choice('Dense_2', [128, 256, 512, 1024]),
#         'Activation_2': hp.choice('Activation_2', ['relu', 'sigmoid']),
#         'Dropout_2': hp.uniform('Dropout_2', 0, 1),
#         'lr': hp.choice('lr', [10**-3, 10**-2, 10**-1]),
#         'lr_1': hp.choice('lr_1', [10**-3, 10**-2, 10**-1]),
#         'lr_2': hp.choice('lr_2', [10**-3, 10**-2, 10**-1]),
#         'choiceval': hp.choice('choiceval', ['adam', 'sgd', 'rmsprop']),
#         'batch_size': hp.choice('batch_size', [128,256,512]),
#     }
#
# >>> Data
#   1:
#   2: (X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()
#   3: X_train, X_val, y_train, y_val = train_test_split(X_train,    y_train, test_size=0.2, random_state=12345)
#   4: X_train = X_train.reshape(48000, 784)
#   5: X_val = X_val.reshape(12000, 784)
#   6: X_train = X_train.astype('float32')
#   7: X_val = X_val.astype('float32')
#   8: X_train /= 255
#   9: X_val /= 255
#  10: nb_classes = 10
#  11: Y_train = np_utils.to_categorical(y_train, nb_classes)
#  12: Y_val = np_utils.to_categorical(y_val, nb_classes)
#  13:
#  14:
#  15:
# >>> Resulting replaced keras model:
#
#    1: def keras_fmin_fnct(space):
#    2:
#    3:
#    4:     model = Sequential()
#    5:     model.add(Dense(space['Dense'], input_shape=(784,)))
#    6:     model.add(Activation(space['Activation']))
#    7:     model.add(Dropout(space['Dropout']))
#    8:     model.add(Dense(space['Dense_1']))
#    9:     model.add(Activation(space['Activation_1']))
#   10:     model.add(Dropout(space['Dropout_1']))
#   11:
#   12:     if (space['if']) == 'three':
#   13:         model.add(Dense(space['Dense_2']))
#   14:         model.add(Activation(space['Activation_2']))
#   15:         model.add(Dropout(space['Dropout_2']))
#   16:
#   17:     model.add(Dense(10))
#   18:     model.add(Activation('softmax'))
#   19:     adam = keras.optimizers.Adam(lr=space['lr'])
#   20:     rmsprop = keras.optimizers.RMSprop(lr=space['lr_1'])
#   21:     sgd = keras.optimizers.SGD(lr=space['lr_2'])
#   22:
#   23:     choiceval = space['choiceval']
#   24:     if choiceval == 'adam':
#   25:         optim = adam
#   26:     elif choiceval == 'rmsprop':
#   27:         optim = rmsprop
#   28:     else:
#   29:         optim = sgd
#   30:
#   31:     model.compile(loss='categorical_crossentropy', metrics=['accuracy'],optimizer=optim)
#   32:     model.fit(X_train, Y_train,
#   33:               batch_size=space['batch_size'],
#   34:               nb_epoch=20,
#   35:               verbose=2,
#   36:               validation_data=(X_val, Y_val))
#   37:     score, acc = model.evaluate(X_val, Y_val, verbose=0)
#   38:     print('Test accuracy:', acc)
#   39:     return {'loss': -acc, 'status': STATUS_OK, 'model': model}
#   40:
#   0%|          | 0/30 [00:00<?, ?it/s, best loss: ?]WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# /content/temp_model.py:102: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/20
#   0%|          | 0/30 [00:00<?, ?it/s, best loss: ?]WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
#  - 3s - loss: 1.2047 - acc: 0.5696 - val_loss: 0.7368 - val_acc: 0.7443
#
# Epoch 2/20
#  - 3s - loss: 0.7277 - acc: 0.7267 - val_loss: 0.6387 - val_acc: 0.7625
#
# Epoch 3/20
#  - 3s - loss: 0.6427 - acc: 0.7604 - val_loss: 0.5752 - val_acc: 0.7929
#
# Epoch 4/20
#  - 3s - loss: 0.5965 - acc: 0.7789 - val_loss: 0.5592 - val_acc: 0.7927
#
# Epoch 5/20
#  - 3s - loss: 0.5594 - acc: 0.7956 - val_loss: 0.5033 - val_acc: 0.8191
#
# Epoch 6/20
#  - 3s - loss: 0.5345 - acc: 0.8051 - val_loss: 0.5014 - val_acc: 0.8162
#
# Epoch 7/20
#  - 3s - loss: 0.5169 - acc: 0.8117 - val_loss: 0.4670 - val_acc: 0.8386
#
# Epoch 8/20
#  - 3s - loss: 0.4999 - acc: 0.8188 - val_loss: 0.4704 - val_acc: 0.8302
#
# Epoch 9/20
#  - 3s - loss: 0.4893 - acc: 0.8220 - val_loss: 0.4532 - val_acc: 0.8393
#
# Epoch 10/20
#  - 3s - loss: 0.4803 - acc: 0.8264 - val_loss: 0.4463 - val_acc: 0.8397
#
# Epoch 11/20
#  - 3s - loss: 0.4701 - acc: 0.8290 - val_loss: 0.4686 - val_acc: 0.8297
#
# Epoch 12/20
#  - 3s - loss: 0.4624 - acc: 0.8321 - val_loss: 0.4180 - val_acc: 0.8550
#
# Epoch 13/20
#  - 3s - loss: 0.4528 - acc: 0.8353 - val_loss: 0.4152 - val_acc: 0.8543
#
# Epoch 14/20
#  - 3s - loss: 0.4470 - acc: 0.8383 - val_loss: 0.4253 - val_acc: 0.8503
#
# Epoch 15/20
#  - 3s - loss: 0.4433 - acc: 0.8391 - val_loss: 0.4065 - val_acc: 0.8568
#
# Epoch 16/20
#  - 3s - loss: 0.4359 - acc: 0.8424 - val_loss: 0.4076 - val_acc: 0.8560
#
# Epoch 17/20
#  - 3s - loss: 0.4315 - acc: 0.8434 - val_loss: 0.3998 - val_acc: 0.8591
#
# Epoch 18/20
#  - 3s - loss: 0.4277 - acc: 0.8466 - val_loss: 0.3952 - val_acc: 0.8597
#
# Epoch 19/20
#  - 3s - loss: 0.4209 - acc: 0.8471 - val_loss: 0.3955 - val_acc: 0.8605
#
# Epoch 20/20
#  - 3s - loss: 0.4186 - acc: 0.8489 - val_loss: 0.3990 - val_acc: 0.8623
#
# Test accuracy:
# 0.86225
#   3%|▎         | 1/30 [00:58<28:06, 58.16s/it, best loss: -0.86225]WARNING:tensorflow:Large dropout rate: 0.966268 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/20
#  - 5s - loss: 14.4528 - acc: 0.0985 - val_loss: 14.4284 - val_acc: 0.1048
#
# Epoch 2/20
#  - 4s - loss: 14.5258 - acc: 0.0988 - val_loss: 14.4284 - val_acc: 0.1048
#
# Epoch 3/20
#  - 4s - loss: 14.5258 - acc: 0.0988 - val_loss: 14.4284 - val_acc: 0.1048
#
# Epoch 4/20
#  - 4s - loss: 14.5258 - acc: 0.0988 - val_loss: 14.4284 - val_acc: 0.1048
#
# Epoch 5/20
#  - 4s - loss: 14.5258 - acc: 0.0988 - val_loss: 14.4284 - val_acc: 0.1048
#
# Epoch 6/20
#  - 4s - loss: 14.5258 - acc: 0.0988 - val_loss: 14.4284 - val_acc: 0.1048
#
# Epoch 7/20
#  - 4s - loss: 14.5258 - acc: 0.0988 - val_loss: 14.4284 - val_acc: 0.1048
#
# Epoch 8/20
#  - 4s - loss: 14.5258 - acc: 0.0988 - val_loss: 14.4284 - val_acc: 0.1048
#
# Epoch 9/20
#  - 4s - loss: 14.5258 - acc: 0.0988 - val_loss: 14.4284 - val_acc: 0.1048
#
# Epoch 10/20
#  - 4s - loss: 14.5258 - acc: 0.0988 - val_loss: 14.4284 - val_acc: 0.1048
#
# Epoch 11/20
#  - 4s - loss: 14.5258 - acc: 0.0988 - val_loss: 14.4284 - val_acc: 0.1048
#
# Epoch 12/20
#  - 4s - loss: 14.5258 - acc: 0.0988 - val_loss: 14.4284 - val_acc: 0.1048
#
# Epoch 13/20
#  - 4s - loss: 14.5258 - acc: 0.0988 - val_loss: 14.4284 - val_acc: 0.1048
#
# Epoch 14/20
#  - 4s - loss: 14.5258 - acc: 0.0988 - val_loss: 14.4284 - val_acc: 0.1048
#
# Epoch 15/20
#  - 4s - loss: 14.5258 - acc: 0.0988 - val_loss: 14.4284 - val_acc: 0.1048
#
# Epoch 16/20
#  - 4s - loss: 14.5258 - acc: 0.0988 - val_loss: 14.4284 - val_acc: 0.1048
#
# Epoch 17/20
#  - 4s - loss: 14.5258 - acc: 0.0988 - val_loss: 14.4284 - val_acc: 0.1048
#
# Epoch 18/20
#  - 4s - loss: 14.5258 - acc: 0.0988 - val_loss: 14.4284 - val_acc: 0.1048
#
# Epoch 19/20
#  - 4s - loss: 14.5258 - acc: 0.0988 - val_loss: 14.4284 - val_acc: 0.1048
#
# Epoch 20/20
#  - 5s - loss: 14.5258 - acc: 0.0988 - val_loss: 14.4284 - val_acc: 0.1048
#
# Test accuracy:
# 0.10483333333333333
#   7%|▋         | 2/30 [02:27<31:28, 67.46s/it, best loss: -0.86225]WARNING:tensorflow:Large dropout rate: 0.636181 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.711425 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/20
#  - 4s - loss: 2.7340 - acc: 0.1050 - val_loss: 2.2681 - val_acc: 0.2541
#
# Epoch 2/20
#  - 4s - loss: 2.5059 - acc: 0.1098 - val_loss: 2.2521 - val_acc: 0.3567
#
# Epoch 3/20
#  - 4s - loss: 2.4054 - acc: 0.1156 - val_loss: 2.2426 - val_acc: 0.4057
#
# Epoch 4/20
#  - 4s - loss: 2.3562 - acc: 0.1233 - val_loss: 2.2364 - val_acc: 0.4202
#
# Epoch 5/20
#  - 4s - loss: 2.3250 - acc: 0.1279 - val_loss: 2.2313 - val_acc: 0.4168
#
# Epoch 6/20
#  - 4s - loss: 2.3016 - acc: 0.1339 - val_loss: 2.2252 - val_acc: 0.4593
#
# Epoch 7/20
#  - 4s - loss: 2.2827 - acc: 0.1376 - val_loss: 2.2181 - val_acc: 0.5005
#
# Epoch 8/20
#  - 4s - loss: 2.2702 - acc: 0.1483 - val_loss: 2.2102 - val_acc: 0.5107
#
# Epoch 9/20
#  - 4s - loss: 2.2596 - acc: 0.1490 - val_loss: 2.2009 - val_acc: 0.5094
#
# Epoch 10/20
#  - 4s - loss: 2.2466 - acc: 0.1547 - val_loss: 2.1897 - val_acc: 0.5071
#
# Epoch 11/20
#  - 4s - loss: 2.2334 - acc: 0.1648 - val_loss: 2.1762 - val_acc: 0.5127
#
# Epoch 12/20
#  - 4s - loss: 2.2202 - acc: 0.1705 - val_loss: 2.1608 - val_acc: 0.5264
#
# Epoch 13/20
#  - 4s - loss: 2.2101 - acc: 0.1722 - val_loss: 2.1439 - val_acc: 0.5283
#
# Epoch 14/20
#  - 4s - loss: 2.1938 - acc: 0.1805 - val_loss: 2.1243 - val_acc: 0.5323
#
# Epoch 15/20
#  - 4s - loss: 2.1783 - acc: 0.1876 - val_loss: 2.1023 - val_acc: 0.5387
#
# Epoch 16/20
#  - 4s - loss: 2.1601 - acc: 0.1924 - val_loss: 2.0768 - val_acc: 0.5370
#
# Epoch 17/20
#  - 4s - loss: 2.1390 - acc: 0.2008 - val_loss: 2.0489 - val_acc: 0.5364
#
# Epoch 18/20
#  - 4s - loss: 2.1199 - acc: 0.2101 - val_loss: 2.0190 - val_acc: 0.5481
#
# Epoch 19/20
#  - 4s - loss: 2.0991 - acc: 0.2139 - val_loss: 1.9876 - val_acc: 0.5415
#
# Epoch 20/20
#  - 4s - loss: 2.0768 - acc: 0.2191 - val_loss: 1.9550 - val_acc: 0.5402
#
# Test accuracy:
# 0.54025
#  10%|█         | 3/30 [03:50<32:25, 72.04s/it, best loss: -0.86225]WARNING:tensorflow:Large dropout rate: 0.997553 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.991201 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/20
#  - 8s - loss: 5.9460 - acc: 0.1028 - val_loss: 2.4354 - val_acc: 0.0912
#
# Epoch 2/20
#  - 8s - loss: 4.0276 - acc: 0.0999 - val_loss: 2.3731 - val_acc: 0.0971
#
# Epoch 3/20
#  - 8s - loss: 3.8602 - acc: 0.0979 - val_loss: 2.4250 - val_acc: 0.0912
#
# Epoch 4/20
#  - 8s - loss: 3.8607 - acc: 0.1006 - val_loss: 2.3547 - val_acc: 0.0978
#
# Epoch 5/20
#  - 8s - loss: 3.8536 - acc: 0.1007 - val_loss: 2.4025 - val_acc: 0.0971
#
# Epoch 6/20
#  - 8s - loss: 3.8903 - acc: 0.1013 - val_loss: 2.3388 - val_acc: 0.0978
#
# Epoch 7/20
#  - 8s - loss: 3.9833 - acc: 0.1020 - val_loss: 2.3626 - val_acc: 0.1048
#
# Epoch 8/20
#  - 8s - loss: 4.0477 - acc: 0.1012 - val_loss: 2.3517 - val_acc: 0.0971
#
# Epoch 9/20
#  - 8s - loss: 4.1948 - acc: 0.1031 - val_loss: 2.3836 - val_acc: 0.0971
#
# Epoch 10/20
#  - 8s - loss: 4.3527 - acc: 0.0999 - val_loss: 2.3271 - val_acc: 0.1030
#
# Epoch 11/20
#  - 8s - loss: 4.5445 - acc: 0.1011 - val_loss: 2.3216 - val_acc: 0.1048
#
# Epoch 12/20
#  - 8s - loss: 4.8876 - acc: 0.0981 - val_loss: 2.3204 - val_acc: 0.1048
#
# Epoch 13/20
#  - 8s - loss: 5.2123 - acc: 0.0986 - val_loss: 2.3157 - val_acc: 0.0912
#
# Epoch 14/20
#  - 8s - loss: 5.4538 - acc: 0.0975 - val_loss: 2.3156 - val_acc: 0.1030
#
# Epoch 15/20
#  - 8s - loss: 5.7219 - acc: 0.0976 - val_loss: 2.3233 - val_acc: 0.0912
#
# Epoch 16/20
#  - 8s - loss: 6.0319 - acc: 0.0975 - val_loss: 2.3452 - val_acc: 0.1048
#
# Epoch 17/20
#  - 8s - loss: 6.2707 - acc: 0.0964 - val_loss: 2.3906 - val_acc: 0.0912
#
# Epoch 18/20
#  - 8s - loss: 6.4139 - acc: 0.1004 - val_loss: 2.3544 - val_acc: 0.1017
#
# Epoch 19/20
#  - 8s - loss: 6.6100 - acc: 0.0995 - val_loss: 2.3771 - val_acc: 0.0912
#
# Epoch 20/20
#  - 8s - loss: 6.7094 - acc: 0.1012 - val_loss: 2.3619 - val_acc: 0.0912
#
# Test accuracy:
# 0.09125
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/20
#  - 8s - loss: 14.3992 - acc: 0.0992 - val_loss: 14.5009 - val_acc: 0.1003
#
# Epoch 2/20
#  - 8s - loss: 14.4914 - acc: 0.1000 - val_loss: 14.4687 - val_acc: 0.1023
#
# Epoch 3/20
#  - 8s - loss: 14.4835 - acc: 0.1006 - val_loss: 14.4687 - val_acc: 0.1023
#
# Epoch 4/20
#  - 8s - loss: 14.4831 - acc: 0.1010 - val_loss: 14.4687 - val_acc: 0.1023
#
# Epoch 5/20
#  - 8s - loss: 14.5073 - acc: 0.0995 - val_loss: 14.4687 - val_acc: 0.1023
#
# Epoch 6/20
#  - 8s - loss: 14.4889 - acc: 0.1008 - val_loss: 14.4687 - val_acc: 0.1023
#
# Epoch 7/20
#  - 8s - loss: 14.5048 - acc: 0.0998 - val_loss: 14.4687 - val_acc: 0.1023
#
# Epoch 8/20
#  - 8s - loss: 14.5075 - acc: 0.0997 - val_loss: 14.5009 - val_acc: 0.1003
#
# Epoch 9/20
#  - 8s - loss: 14.5193 - acc: 0.0990 - val_loss: 14.5009 - val_acc: 0.1003
#
# Epoch 10/20
#  - 8s - loss: 14.4921 - acc: 0.1007 - val_loss: 14.5009 - val_acc: 0.1003
#
# Epoch 11/20
#  - 8s - loss: 14.5016 - acc: 0.1000 - val_loss: 14.5009 - val_acc: 0.1003
#
# Epoch 12/20
#  - 8s - loss: 14.4989 - acc: 0.1003 - val_loss: 14.5009 - val_acc: 0.1003
#
# Epoch 13/20
#  - 8s - loss: 14.5198 - acc: 0.0990 - val_loss: 14.4687 - val_acc: 0.1023
#
# Epoch 14/20
#  - 8s - loss: 14.4842 - acc: 0.1012 - val_loss: 14.4687 - val_acc: 0.1023
#
# Epoch 15/20
#  - 8s - loss: 14.5023 - acc: 0.1001 - val_loss: 14.4687 - val_acc: 0.1023
#
# Epoch 16/20
#  - 8s - loss: 14.5185 - acc: 0.0991 - val_loss: 14.4687 - val_acc: 0.1023
#
# Epoch 17/20
#  - 8s - loss: 14.4741 - acc: 0.1017 - val_loss: 14.4687 - val_acc: 0.1023
#
# Epoch 18/20
#  - 8s - loss: 14.4854 - acc: 0.1012 - val_loss: 14.4687 - val_acc: 0.1023
#
# Epoch 19/20
#  - 8s - loss: 14.5232 - acc: 0.0988 - val_loss: 14.4687 - val_acc: 0.1023
#
# Epoch 20/20
#  - 8s - loss: 14.4820 - acc: 0.1012 - val_loss: 14.5009 - val_acc: 0.1003
#
# Test accuracy:
# 0.10033333333333333
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/20
#  - 9s - loss: 14.4556 - acc: 0.0993 - val_loss: 14.4526 - val_acc: 0.1033
#
# Epoch 2/20
#  - 8s - loss: 14.5197 - acc: 0.0992 - val_loss: 14.4526 - val_acc: 0.1033
#
# Epoch 3/20
#  - 8s - loss: 14.5197 - acc: 0.0992 - val_loss: 14.4526 - val_acc: 0.1033
#
# Epoch 4/20
#  - 8s - loss: 14.5197 - acc: 0.0992 - val_loss: 14.4526 - val_acc: 0.1033
#
# Epoch 5/20
#  - 8s - loss: 14.5197 - acc: 0.0992 - val_loss: 14.4526 - val_acc: 0.1033
#
# Epoch 6/20
#  - 8s - loss: 14.5197 - acc: 0.0992 - val_loss: 14.4526 - val_acc: 0.1033
#
# Epoch 7/20
#  - 8s - loss: 14.5197 - acc: 0.0992 - val_loss: 14.4526 - val_acc: 0.1033
#
# Epoch 8/20
#  - 8s - loss: 14.5197 - acc: 0.0992 - val_loss: 14.4526 - val_acc: 0.1033
#
# Epoch 9/20
#  - 8s - loss: 14.5197 - acc: 0.0992 - val_loss: 14.4526 - val_acc: 0.1033
#
# Epoch 10/20
#  - 9s - loss: 14.5197 - acc: 0.0992 - val_loss: 14.4526 - val_acc: 0.1033
#
# Epoch 11/20
#  - 8s - loss: 14.5197 - acc: 0.0992 - val_loss: 14.4526 - val_acc: 0.1033
#
# Epoch 12/20
#  - 8s - loss: 14.5197 - acc: 0.0992 - val_loss: 14.4526 - val_acc: 0.1033
#
# Epoch 13/20
#  - 8s - loss: 14.5197 - acc: 0.0992 - val_loss: 14.4526 - val_acc: 0.1033
#
# Epoch 14/20
#  - 8s - loss: 14.5197 - acc: 0.0992 - val_loss: 14.4526 - val_acc: 0.1033
#
# Epoch 15/20
#  - 8s - loss: 14.5197 - acc: 0.0992 - val_loss: 14.4526 - val_acc: 0.1033
#
# Epoch 16/20
#  - 8s - loss: 14.5197 - acc: 0.0992 - val_loss: 14.4526 - val_acc: 0.1033
#
# Epoch 17/20
#  - 8s - loss: 14.5197 - acc: 0.0992 - val_loss: 14.4526 - val_acc: 0.1033
#
# Epoch 18/20
#  - 8s - loss: 14.5197 - acc: 0.0992 - val_loss: 14.4526 - val_acc: 0.1033
#
# Epoch 19/20
#  - 9s - loss: 14.5197 - acc: 0.0992 - val_loss: 14.4526 - val_acc: 0.1033
#
# Epoch 20/20
#  - 8s - loss: 14.5197 - acc: 0.0992 - val_loss: 14.4526 - val_acc: 0.1033
#
# Test accuracy:
# 0.10333333333333333
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/20
#  - 4s - loss: 14.3973 - acc: 0.0999 - val_loss: 14.5412 - val_acc: 0.0978
#
# Epoch 2/20
#  - 4s - loss: 14.4976 - acc: 0.1005 - val_loss: 14.5412 - val_acc: 0.0978
#
# Epoch 3/20
#  - 4s - loss: 14.4976 - acc: 0.1005 - val_loss: 14.5412 - val_acc: 0.0978
#
# Epoch 4/20
#  - 4s - loss: 14.4976 - acc: 0.1005 - val_loss: 14.5412 - val_acc: 0.0978
#
# Epoch 5/20
#  - 4s - loss: 14.4976 - acc: 0.1005 - val_loss: 14.5412 - val_acc: 0.0978
#
# Epoch 6/20
#  - 4s - loss: 14.4976 - acc: 0.1005 - val_loss: 14.5412 - val_acc: 0.0978
#
# Epoch 7/20
#  - 4s - loss: 14.4976 - acc: 0.1005 - val_loss: 14.5412 - val_acc: 0.0978
#
# Epoch 8/20
#  - 4s - loss: 14.4976 - acc: 0.1005 - val_loss: 14.5412 - val_acc: 0.0978
#
# Epoch 9/20
#  - 4s - loss: 14.4976 - acc: 0.1005 - val_loss: 14.5412 - val_acc: 0.0978
#
# Epoch 10/20
#  - 4s - loss: 14.4976 - acc: 0.1005 - val_loss: 14.5412 - val_acc: 0.0978
#
# Epoch 11/20
#  - 4s - loss: 14.4976 - acc: 0.1005 - val_loss: 14.5412 - val_acc: 0.0978
#
# Epoch 12/20
#  - 4s - loss: 14.4976 - acc: 0.1005 - val_loss: 14.5412 - val_acc: 0.0978
#
# Epoch 13/20
#  - 4s - loss: 14.4976 - acc: 0.1005 - val_loss: 14.5412 - val_acc: 0.0978
#
# Epoch 14/20
#  - 4s - loss: 14.4976 - acc: 0.1005 - val_loss: 14.5412 - val_acc: 0.0978
#
# Epoch 15/20
#  - 4s - loss: 14.4976 - acc: 0.1005 - val_loss: 14.5412 - val_acc: 0.0978
#
# Epoch 16/20
#  - 4s - loss: 14.4976 - acc: 0.1005 - val_loss: 14.5412 - val_acc: 0.0978
#
# Epoch 17/20
#  - 4s - loss: 14.4976 - acc: 0.1005 - val_loss: 14.5412 - val_acc: 0.0978
#
# Epoch 18/20
#  - 4s - loss: 14.4976 - acc: 0.1005 - val_loss: 14.5412 - val_acc: 0.0978
#
# Epoch 19/20
#  - 4s - loss: 14.4976 - acc: 0.1005 - val_loss: 14.5412 - val_acc: 0.0978
#
# Epoch 20/20
#  - 4s - loss: 14.4976 - acc: 0.1005 - val_loss: 14.5412 - val_acc: 0.0978
#
# Test accuracy:
# 0.09783333333333333
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/20
#  - 8s - loss: 11.2503 - acc: 0.1018 - val_loss: 14.5314 - val_acc: 0.0983
#
# Epoch 2/20
#  - 7s - loss: 10.1316 - acc: 0.1010 - val_loss: 14.5345 - val_acc: 0.0983
#
# Epoch 3/20
#  - 7s - loss: 9.5599 - acc: 0.1050 - val_loss: 14.5345 - val_acc: 0.0983
#
# Epoch 4/20
#  - 8s - loss: 9.6036 - acc: 0.1031 - val_loss: 14.3981 - val_acc: 0.0983
#
# Epoch 5/20
#  - 7s - loss: 9.5087 - acc: 0.1012 - val_loss: 14.5345 - val_acc: 0.0983
#
# Epoch 6/20
#  - 7s - loss: 9.4674 - acc: 0.1032 - val_loss: 14.5345 - val_acc: 0.0983
#
# Epoch 7/20
#  - 7s - loss: 9.3308 - acc: 0.1031 - val_loss: 14.5345 - val_acc: 0.0983
#
# Epoch 8/20
#  - 8s - loss: 9.3237 - acc: 0.1016 - val_loss: 14.5345 - val_acc: 0.0983
#
# Epoch 9/20
#  - 8s - loss: 9.3402 - acc: 0.1045 - val_loss: 14.5345 - val_acc: 0.0983
#
# Epoch 10/20
#  - 8s - loss: 9.2523 - acc: 0.1032 - val_loss: 14.5345 - val_acc: 0.0983
#
# Epoch 11/20
#  - 8s - loss: 9.2831 - acc: 0.1048 - val_loss: 14.5345 - val_acc: 0.0983
#
# Epoch 12/20
#  - 8s - loss: 9.3243 - acc: 0.1034 - val_loss: 14.5345 - val_acc: 0.0983
#
# Epoch 13/20
#  - 8s - loss: 9.2726 - acc: 0.1034 - val_loss: 14.5345 - val_acc: 0.0983
#
# Epoch 14/20
#  - 8s - loss: 9.1896 - acc: 0.1041 - val_loss: 14.5345 - val_acc: 0.0983
#
# Epoch 15/20
#  - 8s - loss: 9.2175 - acc: 0.1053 - val_loss: 14.5345 - val_acc: 0.0983
#
# Epoch 16/20
#  - 8s - loss: 9.1743 - acc: 0.1047 - val_loss: 14.5345 - val_acc: 0.0983
#
# Epoch 17/20
#  - 8s - loss: 9.1982 - acc: 0.1048 - val_loss: 14.5345 - val_acc: 0.0983
#
# Epoch 18/20
#  - 8s - loss: 9.1858 - acc: 0.1029 - val_loss: 14.5345 - val_acc: 0.0983
#
# Epoch 19/20
#  - 8s - loss: 9.0886 - acc: 0.1057 - val_loss: 14.5345 - val_acc: 0.0983
#
# Epoch 20/20
#  - 7s - loss: 9.1043 - acc: 0.1055 - val_loss: 14.5345 - val_acc: 0.0983
#
# Test accuracy:
# 0.09825
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/20
#  - 3s - loss: 3.2780 - acc: 0.0994 - val_loss: 2.3377 - val_acc: 0.1030
#
# Epoch 2/20
#  - 2s - loss: 3.2036 - acc: 0.0994 - val_loss: 2.3063 - val_acc: 0.0886
#
# Epoch 3/20
#  - 2s - loss: 3.1683 - acc: 0.0998 - val_loss: 2.3005 - val_acc: 0.0927
#
# Epoch 4/20
#  - 2s - loss: 3.1391 - acc: 0.1009 - val_loss: 2.2990 - val_acc: 0.0915
#
# Epoch 5/20
#  - 2s - loss: 3.1274 - acc: 0.1006 - val_loss: 2.2981 - val_acc: 0.0832
#
# Epoch 6/20
#  - 2s - loss: 3.1237 - acc: 0.1016 - val_loss: 2.2975 - val_acc: 0.0895
#
# Epoch 7/20
#  - 2s - loss: 3.0897 - acc: 0.1025 - val_loss: 2.2968 - val_acc: 0.0950
#
# Epoch 8/20
#  - 2s - loss: 3.0840 - acc: 0.1004 - val_loss: 2.2962 - val_acc: 0.1042
#
# Epoch 9/20
#  - 2s - loss: 3.0716 - acc: 0.0998 - val_loss: 2.2956 - val_acc: 0.1130
#
# Epoch 10/20
#  - 2s - loss: 3.0467 - acc: 0.0979 - val_loss: 2.2949 - val_acc: 0.1089
#
# Epoch 11/20
#  - 2s - loss: 3.0321 - acc: 0.1014 - val_loss: 2.2944 - val_acc: 0.1204
#
# Epoch 12/20
#  - 2s - loss: 3.0215 - acc: 0.1007 - val_loss: 2.2936 - val_acc: 0.1373
#
# Epoch 13/20
#  - 2s - loss: 2.9982 - acc: 0.1016 - val_loss: 2.2930 - val_acc: 0.1393
#
# Epoch 14/20
#  - 2s - loss: 2.9809 - acc: 0.1023 - val_loss: 2.2923 - val_acc: 0.1326
#
# Epoch 15/20
#  - 2s - loss: 2.9767 - acc: 0.1017 - val_loss: 2.2918 - val_acc: 0.1655
#
# Epoch 16/20
#  - 2s - loss: 2.9505 - acc: 0.1019 - val_loss: 2.2913 - val_acc: 0.1454
#
# Epoch 17/20
#  - 2s - loss: 2.9446 - acc: 0.1021 - val_loss: 2.2908 - val_acc: 0.1728
#
# Epoch 18/20
#  - 2s - loss: 2.9255 - acc: 0.1040 - val_loss: 2.2904 - val_acc: 0.1901
#
# Epoch 19/20
#  - 2s - loss: 2.9256 - acc: 0.1006 - val_loss: 2.2899 - val_acc: 0.1762
#
# Epoch 20/20
#  - 2s - loss: 2.9001 - acc: 0.1022 - val_loss: 2.2894 - val_acc: 0.1676
#
# Test accuracy:
# 0.16758333333333333
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/20
#  - 4s - loss: 1.2782 - acc: 0.5303 - val_loss: 0.6439 - val_acc: 0.7710
#
# Epoch 2/20
#  - 3s - loss: 0.8914 - acc: 0.6654 - val_loss: 0.5902 - val_acc: 0.8140
#
# Epoch 3/20
#  - 3s - loss: 0.8151 - acc: 0.6927 - val_loss: 0.5564 - val_acc: 0.8348
#
# Epoch 4/20
#  - 3s - loss: 0.7757 - acc: 0.7150 - val_loss: 0.5469 - val_acc: 0.8242
#
# Epoch 5/20
#  - 3s - loss: 0.7613 - acc: 0.7268 - val_loss: 0.5364 - val_acc: 0.7854
#
# Epoch 6/20
#  - 3s - loss: 0.7448 - acc: 0.7355 - val_loss: 0.5145 - val_acc: 0.8242
#
# Epoch 7/20
#  - 3s - loss: 0.7318 - acc: 0.7405 - val_loss: 0.5118 - val_acc: 0.8345
#
# Epoch 8/20
#  - 3s - loss: 0.7266 - acc: 0.7427 - val_loss: 0.5043 - val_acc: 0.8436
#
# Epoch 9/20
#  - 3s - loss: 0.7185 - acc: 0.7459 - val_loss: 0.5044 - val_acc: 0.8356
#
# Epoch 10/20
#  - 3s - loss: 0.7063 - acc: 0.7515 - val_loss: 0.4847 - val_acc: 0.8527
#
# Epoch 11/20
#  - 3s - loss: 0.7171 - acc: 0.7488 - val_loss: 0.4838 - val_acc: 0.8500
#
# Epoch 12/20
#  - 3s - loss: 0.7127 - acc: 0.7505 - val_loss: 0.4793 - val_acc: 0.8558
#
# Epoch 13/20
#  - 3s - loss: 0.7060 - acc: 0.7537 - val_loss: 0.4790 - val_acc: 0.8461
#
# Epoch 14/20
#  - 3s - loss: 0.7108 - acc: 0.7547 - val_loss: 0.4851 - val_acc: 0.8418
#
# Epoch 15/20
#  - 3s - loss: 0.7206 - acc: 0.7534 - val_loss: 0.4913 - val_acc: 0.8426
#
# Epoch 16/20
#  - 3s - loss: 0.7119 - acc: 0.7565 - val_loss: 0.4818 - val_acc: 0.8487
#
# Epoch 17/20
#  - 3s - loss: 0.7163 - acc: 0.7546 - val_loss: 0.4680 - val_acc: 0.8572
#
# Epoch 18/20
#  - 3s - loss: 0.7187 - acc: 0.7544 - val_loss: 0.4831 - val_acc: 0.8481
#
# Epoch 19/20
#  - 3s - loss: 0.7235 - acc: 0.7533 - val_loss: 0.5045 - val_acc: 0.8408
#
# Epoch 20/20
#  - 3s - loss: 0.7241 - acc: 0.7578 - val_loss: 0.5013 - val_acc: 0.8529
#
# Test accuracy:
# 0.8529166666666667
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/20
#  - 2s - loss: 2.3813 - acc: 0.1249 - val_loss: 2.1670 - val_acc: 0.3929
#
# Epoch 2/20
#  - 1s - loss: 2.2023 - acc: 0.1813 - val_loss: 2.0609 - val_acc: 0.4793
#
# Epoch 3/20
#  - 1s - loss: 2.0959 - acc: 0.2377 - val_loss: 1.9293 - val_acc: 0.5093
#
# Epoch 4/20
#  - 1s - loss: 1.9905 - acc: 0.2790 - val_loss: 1.7910 - val_acc: 0.5280
#
# Epoch 5/20
#  - 1s - loss: 1.8849 - acc: 0.3159 - val_loss: 1.6633 - val_acc: 0.5607
#
# Epoch 6/20
#  - 1s - loss: 1.7863 - acc: 0.3438 - val_loss: 1.5527 - val_acc: 0.5894
#
# Epoch 7/20
#  - 1s - loss: 1.7002 - acc: 0.3709 - val_loss: 1.4567 - val_acc: 0.6051
#
# Epoch 8/20
#  - 1s - loss: 1.6247 - acc: 0.3921 - val_loss: 1.3758 - val_acc: 0.6225
#
# Epoch 9/20
#  - 1s - loss: 1.5517 - acc: 0.4220 - val_loss: 1.3066 - val_acc: 0.6309
#
# Epoch 10/20
#  - 1s - loss: 1.4949 - acc: 0.4369 - val_loss: 1.2489 - val_acc: 0.6413
#
# Epoch 11/20
#  - 1s - loss: 1.4412 - acc: 0.4544 - val_loss: 1.1958 - val_acc: 0.6467
#
# Epoch 12/20
#  - 1s - loss: 1.4021 - acc: 0.4683 - val_loss: 1.1530 - val_acc: 0.6476
#
# Epoch 13/20
#  - 1s - loss: 1.3552 - acc: 0.4878 - val_loss: 1.1114 - val_acc: 0.6512
#
# Epoch 14/20
#  - 1s - loss: 1.3213 - acc: 0.4984 - val_loss: 1.0788 - val_acc: 0.6555
#
# Epoch 15/20
#  - 1s - loss: 1.2849 - acc: 0.5123 - val_loss: 1.0476 - val_acc: 0.6670
#
# Epoch 16/20
#  - 1s - loss: 1.2593 - acc: 0.5230 - val_loss: 1.0218 - val_acc: 0.6765
#
# Epoch 17/20
#  - 1s - loss: 1.2284 - acc: 0.5370 - val_loss: 0.9953 - val_acc: 0.6856
#
# Epoch 18/20
#  - 1s - loss: 1.2046 - acc: 0.5446 - val_loss: 0.9733 - val_acc: 0.6865
#
# Epoch 19/20
#  - 1s - loss: 1.1832 - acc: 0.5532 - val_loss: 0.9533 - val_acc: 0.6909
#
# Epoch 20/20
#  - 1s - loss: 1.1619 - acc: 0.5602 - val_loss: 0.9349 - val_acc: 0.6962
#
# Test accuracy:
# 0.6961666666666667
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/20
#  - 6s - loss: 2.2442 - acc: 0.1736 - val_loss: 2.0034 - val_acc: 0.5516
#
# Epoch 2/20
#  - 5s - loss: 1.9624 - acc: 0.3317 - val_loss: 1.7557 - val_acc: 0.6263
#
# Epoch 3/20
#  - 5s - loss: 1.7260 - acc: 0.4400 - val_loss: 1.5317 - val_acc: 0.6563
#
# Epoch 4/20
#  - 5s - loss: 1.5300 - acc: 0.5060 - val_loss: 1.3564 - val_acc: 0.6872
#
# Epoch 5/20
#  - 5s - loss: 1.3817 - acc: 0.5481 - val_loss: 1.2258 - val_acc: 0.6956
#
# Epoch 6/20
#  - 5s - loss: 1.2736 - acc: 0.5747 - val_loss: 1.1293 - val_acc: 0.7027
#
# Epoch 7/20
#  - 5s - loss: 1.1855 - acc: 0.6033 - val_loss: 1.0551 - val_acc: 0.7086
#
# Epoch 8/20
#  - 5s - loss: 1.1205 - acc: 0.6206 - val_loss: 0.9945 - val_acc: 0.7150
#
# Epoch 9/20
#  - 5s - loss: 1.0641 - acc: 0.6344 - val_loss: 0.9450 - val_acc: 0.7199
#
# Epoch 10/20
#  - 5s - loss: 1.0205 - acc: 0.6444 - val_loss: 0.9044 - val_acc: 0.7261
#
# Epoch 11/20
#  - 5s - loss: 0.9759 - acc: 0.6615 - val_loss: 0.8691 - val_acc: 0.7272
#
# Epoch 12/20
#  - 5s - loss: 0.9464 - acc: 0.6687 - val_loss: 0.8400 - val_acc: 0.7320
#
# Epoch 13/20
#  - 5s - loss: 0.9131 - acc: 0.6795 - val_loss: 0.8148 - val_acc: 0.7330
#
# Epoch 14/20
#  - 5s - loss: 0.8908 - acc: 0.6875 - val_loss: 0.7923 - val_acc: 0.7361
#
# Epoch 15/20
#  - 5s - loss: 0.8688 - acc: 0.6887 - val_loss: 0.7723 - val_acc: 0.7380
#
# Epoch 16/20
#  - 5s - loss: 0.8480 - acc: 0.6987 - val_loss: 0.7549 - val_acc: 0.7437
#
# Epoch 17/20
#  - 5s - loss: 0.8297 - acc: 0.7049 - val_loss: 0.7406 - val_acc: 0.7423
#
# Epoch 18/20
#  - 5s - loss: 0.8166 - acc: 0.7061 - val_loss: 0.7266 - val_acc: 0.7451
#
# Epoch 19/20
#  - 5s - loss: 0.8007 - acc: 0.7111 - val_loss: 0.7140 - val_acc: 0.7496
#
# Epoch 20/20
#  - 5s - loss: 0.7875 - acc: 0.7156 - val_loss: 0.7048 - val_acc: 0.7503
#
# Test accuracy:
# 0.75025
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/20
#  - 11s - loss: 2.4494 - acc: 0.1091 - val_loss: 2.2334 - val_acc: 0.1783
#
# Epoch 2/20
#  - 10s - loss: 2.3528 - acc: 0.1342 - val_loss: 2.1703 - val_acc: 0.3932
#
# Epoch 3/20
#  - 10s - loss: 2.2579 - acc: 0.1710 - val_loss: 2.0759 - val_acc: 0.4228
#
# Epoch 4/20
#  - 10s - loss: 2.1679 - acc: 0.2037 - val_loss: 1.9815 - val_acc: 0.5431
#
# Epoch 5/20
#  - 11s - loss: 2.0623 - acc: 0.2476 - val_loss: 1.8722 - val_acc: 0.5986
#
# Epoch 6/20
#  - 11s - loss: 1.9469 - acc: 0.2873 - val_loss: 1.7536 - val_acc: 0.6431
#
# Epoch 7/20
#  - 11s - loss: 1.8335 - acc: 0.3292 - val_loss: 1.6361 - val_acc: 0.6272
#
# Epoch 8/20
#  - 10s - loss: 1.7266 - acc: 0.3656 - val_loss: 1.5356 - val_acc: 0.6288
#
# Epoch 9/20
#  - 11s - loss: 1.6283 - acc: 0.3983 - val_loss: 1.4425 - val_acc: 0.6449
#
# Epoch 10/20
#  - 11s - loss: 1.5457 - acc: 0.4233 - val_loss: 1.3663 - val_acc: 0.5857
#
# Epoch 11/20
#  - 11s - loss: 1.4700 - acc: 0.4473 - val_loss: 1.2994 - val_acc: 0.6668
#
# Epoch 12/20
#  - 11s - loss: 1.4081 - acc: 0.4690 - val_loss: 1.2407 - val_acc: 0.6239
#
# Epoch 13/20
#  - 11s - loss: 1.3479 - acc: 0.4923 - val_loss: 1.1911 - val_acc: 0.6284
#
# Epoch 14/20
#  - 11s - loss: 1.3016 - acc: 0.5083 - val_loss: 1.1503 - val_acc: 0.6802
#
# Epoch 15/20
#  - 11s - loss: 1.2609 - acc: 0.5240 - val_loss: 1.1140 - val_acc: 0.6484
#
# Epoch 16/20
#  - 10s - loss: 1.2282 - acc: 0.5334 - val_loss: 1.0797 - val_acc: 0.6583
#
# Epoch 17/20
#  - 10s - loss: 1.1946 - acc: 0.5452 - val_loss: 1.0512 - val_acc: 0.6744
#
# Epoch 18/20
#  - 10s - loss: 1.1647 - acc: 0.5563 - val_loss: 1.0268 - val_acc: 0.6653
#
# Epoch 19/20
#  - 11s - loss: 1.1359 - acc: 0.5717 - val_loss: 1.0033 - val_acc: 0.6779
#
# Epoch 20/20
#  - 10s - loss: 1.1165 - acc: 0.5764 - val_loss: 0.9825 - val_acc: 0.6788
#
# Test accuracy:
# 0.67875
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/20
#  - 16s - loss: 14.3706 - acc: 0.1005 - val_loss: 14.5412 - val_acc: 0.0978
#
# Epoch 2/20
#  - 15s - loss: 14.4976 - acc: 0.1005 - val_loss: 14.5412 - val_acc: 0.0978
#
# Epoch 3/20
#  - 14s - loss: 14.4976 - acc: 0.1005 - val_loss: 14.5412 - val_acc: 0.0978
#
# Epoch 4/20
#  - 14s - loss: 14.4976 - acc: 0.1005 - val_loss: 14.5412 - val_acc: 0.0978
#
# Epoch 5/20
#  - 14s - loss: 14.4976 - acc: 0.1005 - val_loss: 14.5412 - val_acc: 0.0978
#
# Epoch 6/20
#  - 14s - loss: 14.4976 - acc: 0.1005 - val_loss: 14.5412 - val_acc: 0.0978
#
# Epoch 7/20
#  - 15s - loss: 14.4976 - acc: 0.1005 - val_loss: 14.5412 - val_acc: 0.0978
#
# Epoch 8/20
#  - 14s - loss: 14.4976 - acc: 0.1005 - val_loss: 14.5412 - val_acc: 0.0978
#
# Epoch 9/20
#  - 14s - loss: 14.4976 - acc: 0.1005 - val_loss: 14.5412 - val_acc: 0.0978
#
# Epoch 10/20
#  - 14s - loss: 14.4976 - acc: 0.1005 - val_loss: 14.5412 - val_acc: 0.0978
#
# Epoch 11/20
#  - 15s - loss: 14.4976 - acc: 0.1005 - val_loss: 14.5412 - val_acc: 0.0978
#
# Epoch 12/20
#  - 14s - loss: 14.4976 - acc: 0.1005 - val_loss: 14.5412 - val_acc: 0.0978
#
# Epoch 13/20
#  - 15s - loss: 14.4976 - acc: 0.1005 - val_loss: 14.5412 - val_acc: 0.0978
#
# Epoch 14/20
#  - 14s - loss: 14.4976 - acc: 0.1005 - val_loss: 14.5412 - val_acc: 0.0978
#
# Epoch 15/20
#  - 14s - loss: 14.4976 - acc: 0.1005 - val_loss: 14.5412 - val_acc: 0.0978
#
# Epoch 16/20
#  - 14s - loss: 14.4976 - acc: 0.1005 - val_loss: 14.5412 - val_acc: 0.0978
#
# Epoch 17/20
#  - 14s - loss: 14.4976 - acc: 0.1005 - val_loss: 14.5412 - val_acc: 0.0978
#
# Epoch 18/20
#  - 14s - loss: 14.4976 - acc: 0.1005 - val_loss: 14.5412 - val_acc: 0.0978
#
# Epoch 19/20
#  - 14s - loss: 14.4976 - acc: 0.1005 - val_loss: 14.5412 - val_acc: 0.0978
#
# Epoch 20/20
#  - 14s - loss: 14.4976 - acc: 0.1005 - val_loss: 14.5412 - val_acc: 0.0978
#
# Test accuracy:
# 0.09783333333333333
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/20
#  - 7s - loss: 2.3696 - acc: 0.1062 - val_loss: 2.2983 - val_acc: 0.0980
#
# Epoch 2/20
#  - 5s - loss: 2.3159 - acc: 0.1055 - val_loss: 2.3008 - val_acc: 0.1738
#
# Epoch 3/20
#  - 5s - loss: 2.3067 - acc: 0.1083 - val_loss: 2.2991 - val_acc: 0.1207
#
# Epoch 4/20
#  - 5s - loss: 2.3030 - acc: 0.1121 - val_loss: 2.2974 - val_acc: 0.1618
#
# Epoch 5/20
#  - 5s - loss: 2.2992 - acc: 0.1161 - val_loss: 2.2960 - val_acc: 0.1747
#
# Epoch 6/20
#  - 5s - loss: 2.2981 - acc: 0.1193 - val_loss: 2.2915 - val_acc: 0.2339
#
# Epoch 7/20
#  - 5s - loss: 2.2930 - acc: 0.1227 - val_loss: 2.2831 - val_acc: 0.2060
#
# Epoch 8/20
#  - 5s - loss: 2.2888 - acc: 0.1217 - val_loss: 2.2732 - val_acc: 0.1023
#
# Epoch 9/20
#  - 5s - loss: 2.2812 - acc: 0.1311 - val_loss: 2.2541 - val_acc: 0.2845
#
# Epoch 10/20
#  - 5s - loss: 2.2678 - acc: 0.1388 - val_loss: 2.2255 - val_acc: 0.2697
#
# Epoch 11/20
#  - 5s - loss: 2.2471 - acc: 0.1476 - val_loss: 2.1882 - val_acc: 0.3211
#
# Epoch 12/20
#  - 5s - loss: 2.2160 - acc: 0.1583 - val_loss: 2.1291 - val_acc: 0.2982
#
# Epoch 13/20
#  - 5s - loss: 2.1681 - acc: 0.1709 - val_loss: 2.0406 - val_acc: 0.3014
#
# Epoch 14/20
#  - 5s - loss: 2.0995 - acc: 0.1898 - val_loss: 1.9431 - val_acc: 0.2435
#
# Epoch 15/20
#  - 5s - loss: 2.0167 - acc: 0.2089 - val_loss: 1.8364 - val_acc: 0.2593
#
# Epoch 16/20
#  - 5s - loss: 1.9406 - acc: 0.2158 - val_loss: 1.7578 - val_acc: 0.2374
#
# Epoch 17/20
#  - 5s - loss: 1.8784 - acc: 0.2294 - val_loss: 1.7025 - val_acc: 0.2634
#
# Epoch 18/20
#  - 5s - loss: 1.8296 - acc: 0.2435 - val_loss: 1.6621 - val_acc: 0.3582
#
# Epoch 19/20
#  - 5s - loss: 1.7888 - acc: 0.2509 - val_loss: 1.6280 - val_acc: 0.3991
#
# Epoch 20/20
#  - 5s - loss: 1.7535 - acc: 0.2654 - val_loss: 1.5958 - val_acc: 0.4254
#
# Test accuracy:
# 0.42541666666666667
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/20
#  - 15s - loss: 0.7325 - acc: 0.7347 - val_loss: 0.4471 - val_acc: 0.8350
#
# Epoch 2/20
#  - 14s - loss: 0.5142 - acc: 0.8135 - val_loss: 0.3928 - val_acc: 0.8573
#
# Epoch 3/20
#  - 14s - loss: 0.4707 - acc: 0.8290 - val_loss: 0.3650 - val_acc: 0.8678
#
# Epoch 4/20
#  - 14s - loss: 0.4508 - acc: 0.8355 - val_loss: 0.3763 - val_acc: 0.8639
#
# Epoch 5/20
#  - 14s - loss: 0.4363 - acc: 0.8421 - val_loss: 0.3537 - val_acc: 0.8743
#
# Epoch 6/20
#  - 14s - loss: 0.4167 - acc: 0.8483 - val_loss: 0.3458 - val_acc: 0.8764
#
# Epoch 7/20
#  - 14s - loss: 0.4113 - acc: 0.8486 - val_loss: 0.3349 - val_acc: 0.8803
#
# Epoch 8/20
#  - 14s - loss: 0.4002 - acc: 0.8546 - val_loss: 0.3258 - val_acc: 0.8841
#
# Epoch 9/20
#  - 14s - loss: 0.3933 - acc: 0.8570 - val_loss: 0.3180 - val_acc: 0.8858
#
# Epoch 10/20
#  - 14s - loss: 0.3832 - acc: 0.8597 - val_loss: 0.3190 - val_acc: 0.8862
#
# Epoch 11/20
#  - 14s - loss: 0.3810 - acc: 0.8607 - val_loss: 0.3146 - val_acc: 0.8863
#
# Epoch 12/20
#  - 14s - loss: 0.3652 - acc: 0.8662 - val_loss: 0.3183 - val_acc: 0.8847
#
# Epoch 13/20
#  - 14s - loss: 0.3706 - acc: 0.8631 - val_loss: 0.3101 - val_acc: 0.8883
#
# Epoch 14/20
#  - 14s - loss: 0.3653 - acc: 0.8659 - val_loss: 0.3146 - val_acc: 0.8886
#
# Epoch 15/20
#  - 14s - loss: 0.3623 - acc: 0.8661 - val_loss: 0.3064 - val_acc: 0.8874
#
# Epoch 16/20
#  - 14s - loss: 0.3524 - acc: 0.8703 - val_loss: 0.3111 - val_acc: 0.8924
#
# Epoch 17/20
#  - 14s - loss: 0.3500 - acc: 0.8725 - val_loss: 0.2910 - val_acc: 0.8947
#
# Epoch 18/20
#  - 14s - loss: 0.3481 - acc: 0.8709 - val_loss: 0.2970 - val_acc: 0.8920
#
# Epoch 19/20
#  - 14s - loss: 0.3426 - acc: 0.8748 - val_loss: 0.3085 - val_acc: 0.8855
#
# Epoch 20/20
#  - 15s - loss: 0.3417 - acc: 0.8733 - val_loss: 0.3135 - val_acc: 0.8892
#
# Test accuracy:
# 0.88925
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/20
#  - 6s - loss: 2.1032 - acc: 0.2241 - val_loss: 1.5268 - val_acc: 0.5574
#
# Epoch 2/20
#  - 5s - loss: 1.5689 - acc: 0.4011 - val_loss: 1.0884 - val_acc: 0.6189
#
# Epoch 3/20
#  - 5s - loss: 1.3279 - acc: 0.4798 - val_loss: 0.9261 - val_acc: 0.6551
#
# Epoch 4/20
#  - 5s - loss: 1.1946 - acc: 0.5331 - val_loss: 0.8390 - val_acc: 0.7036
#
# Epoch 5/20
#  - 5s - loss: 1.1044 - acc: 0.5691 - val_loss: 0.7810 - val_acc: 0.7052
#
# Epoch 6/20
#  - 5s - loss: 1.0449 - acc: 0.5938 - val_loss: 0.7531 - val_acc: 0.7312
#
# Epoch 7/20
#  - 5s - loss: 0.9997 - acc: 0.6109 - val_loss: 0.7237 - val_acc: 0.7428
#
# Epoch 8/20
#  - 5s - loss: 0.9625 - acc: 0.6268 - val_loss: 0.7007 - val_acc: 0.7593
#
# Epoch 9/20
#  - 4s - loss: 0.9316 - acc: 0.6428 - val_loss: 0.6846 - val_acc: 0.7586
#
# Epoch 10/20
#  53%|█████▎    | 16/30 [35:31<44:49, 192.13s/it, best loss: -0.88925]
